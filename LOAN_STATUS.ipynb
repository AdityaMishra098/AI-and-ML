# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/loan_data.csv')

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001003    Male     Yes          1      Graduate            No
# 1    LP001005    Male     Yes          0      Graduate           Yes
# 2    LP001006    Male     Yes          0  Not Graduate            No
# 3    LP001008    Male      No          0      Graduate            No
# 4    LP001013    Male     Yes          0  Not Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 376  LP002953    Male     Yes         3+      Graduate            No
# 377  LP002974    Male     Yes          0      Graduate            No
# 378  LP002978  Female      No          0      Graduate            No
# 379  LP002979    Male     Yes         3+      Graduate            No
# 380  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001003   Male     Yes          1      Graduate            No
# 1  LP001005   Male     Yes          0      Graduate           Yes
# 2  LP001006   Male     Yes          0  Not Graduate            No
# 3  LP001008   Male      No          0      Graduate            No
# 4  LP001013   Male     Yes          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0       128.0             360.0
# 1             3000                0.0        66.0             360.0
# 2             2583             2358.0       120.0             360.0
# 3             6000                0.0       141.0             360.0
# 4             2333             1516.0        95.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Rural           N
# 1             1.0         Urban           Y
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 376  LP002953    Male     Yes         3+  Graduate            No
# 377  LP002974    Male     Yes          0  Graduate            No
# 378  LP002978  Female      No          0  Graduate            No
# 379  LP002979    Male     Yes         3+  Graduate            No
# 380  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 376             5703                0.0       128.0             360.0
# 377             3232             1950.0       108.0             360.0
# 378             2900                0.0        71.0             360.0
# 379             4106                0.0        40.0             180.0
# 380             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 376             1.0         Urban           Y
# 377             1.0         Rural           Y
# ...

# %%
df.describe().T
# Out:
#                    count         mean          std    min     25%     50%  \
# ApplicantIncome    381.0  3579.845144  1419.813818  150.0  2600.0  3333.0
# CoapplicantIncome  381.0  1277.275381  2340.818114    0.0     0.0   983.0
# LoanAmount         381.0   104.986877    28.358464    9.0    90.0   110.0
# Loan_Amount_Term   370.0   340.864865    68.549257   12.0   360.0   360.0
# Credit_History     351.0     0.837607     0.369338    0.0     1.0     1.0
#
#                       75%      max
# ApplicantIncome    4288.0   9703.0
# CoapplicantIncome  2016.0  33837.0
# LoanAmount          127.0    150.0
# Loan_Amount_Term    360.0    480.0
# Credit_History        1.0      1.0

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 381 entries, 0 to 380
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            381 non-null    object
#  1   Gender             376 non-null    object
#  2   Married            381 non-null    object
#  3   Dependents         373 non-null    object
#  4   Education          381 non-null    object
#  5   Self_Employed      360 non-null    object
#  6   ApplicantIncome    381 non-null    int64
#  7   CoapplicantIncome  381 non-null    float64
#  8   LoanAmount         381 non-null    float64
#  9   Loan_Amount_Term   370 non-null    float64
#  10  Credit_History     351 non-null    float64
#  11  Property_Area      381 non-null    object
#  12  Loan_Status        381 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 38.8+ KB

# %%
df.shape
# Out:
# (381, 13)

# %%
df.size
# Out:
# 4953

# %%
df.nunique()
# Out:
# Loan_ID              381
# Gender                 2
# Married                2
# Dependents             4
# Education              2
# Self_Employed          2
# ApplicantIncome      322
# CoapplicantIncome    182
# LoanAmount           101
# Loan_Amount_Term      10
# Credit_History         2
# Property_Area          3
# Loan_Status            2
# dtype: int64

# %%
sns.countplot(data=df,x='Gender',hue='Loan_Status')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %%
sns.countplot(data=df,x='Married',hue='Loan_Status')
# Out:
# <Axes: xlabel='Married', ylabel='count'>

# %%
sns.countplot(data=df,x='Education',hue='Loan_Status')
# Out:
# <Axes: xlabel='Education', ylabel='count'>

# %%
df.groupby('Education')['LoanAmount'].count()
# Out:
# Education
# Graduate        278
# Not Graduate    103
# Name: LoanAmount, dtype: int64

# %%
sns.countplot(data=df,x='Dependents',hue='Loan_Status')
# Out:
# <Axes: xlabel='Dependents', ylabel='count'>

# %%
sns.barplot(data=df,x='Self_Employed',y='LoanAmount',hue='Loan_Status')
# Out:
# <Axes: xlabel='Self_Employed', ylabel='LoanAmount'>

# %%
df.groupby('Self_Employed')['LoanAmount'].mean()
# Out:
# Self_Employed
# No     104.513846
# Yes    107.314286
# Name: LoanAmount, dtype: float64

# %%
df.groupby(['Self_Employed','Gender'])['LoanAmount'].mean()
# Out:
# Self_Employed  Gender
# No             Female     99.257143
#                Male      105.796000
# Yes            Female    112.750000
#                Male      105.703704
# Name: LoanAmount, dtype: float64

# %%
sns.barplot(data=df,x='Gender',y='LoanAmount',hue='Self_Employed')
# Out:
# <Axes: xlabel='Gender', ylabel='LoanAmount'>

# %%
df.groupby(['Gender','Self_Employed'])['LoanAmount'].mean()
# Out:
# Gender  Self_Employed
# Female  No                99.257143
#         Yes              112.750000
# Male    No               105.796000
#         Yes              105.703704
# Name: LoanAmount, dtype: float64

# %%
sns.scatterplot(data=df,x='ApplicantIncome',y='LoanAmount',hue='Loan_Status')
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='LoanAmount'>

# %%
sns.boxplot(data=df,x='Loan_Status',y='ApplicantIncome')
# Out:
# <Axes: xlabel='Loan_Status', ylabel='ApplicantIncome'>

# %%
sns.histplot (data=df,x='ApplicantIncome',kde=True,hue='Loan_Status')
# Out:
# <Axes: xlabel='ApplicantIncome', ylabel='Count'>

# %%
dlable_df=df['Loan_Status'].value_counts()

# %%
value_df=df['Loan_Status'].value_counts().values

# %%
plt.pie(value_df,labels=dlable_df.index,autopct='%1.2f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x7c39d6a42e90>,
# ...
#  [Text(-0.6777040727732003, 0.8664393745361627, 'Y'),
#   Text(0.6777041485197366, -0.8664393152893854, 'N')],
#  [Text(-0.3696567669672002, 0.47260329520154326, '71.13%'),
#   Text(0.3696568082834926, -0.4726032628851192, '28.87%')])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df['Married']=le.fit_transform(df['Married'])

# %%
df['Education']=le.fit_transform(df['Education'])

# %%
df['Dependents']=le.fit_transform(df['Dependents'])

# %%
df['Loan_Status']=le.fit_transform(df['Loan_Status'])

# %%
df['Self_Employed']=le.fit_transform(df['Self_Employed'])

# %%
df['Property_Area']=le.fit_transform(df['Property_Area'])

# %%
df['PLoan_ID']=le.fit_transform(df['Loan_ID'])

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status',
#        'PLoan_ID'],
#       dtype='object')

# %%
df.head()
# Out:
#     Loan_ID  Gender  Married  Dependents  Education  Self_Employed  \
# 0  LP001003       1        1           1          0              0
# 1  LP001005       1        1           0          0              1
# 2  LP001006       1        1           0          1              0
# 3  LP001008       1        0           0          0              0
# 4  LP001013       1        1           0          1              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             4583             1508.0       128.0             360.0
# 1             3000                0.0        66.0             360.0
# 2             2583             2358.0       120.0             360.0
# 3             6000                0.0       141.0             360.0
# 4             2333             1516.0        95.0             360.0
#
#    Credit_History  Property_Area  Loan_Status  PLoan_ID
# 0             1.0              0            0         0
# ...

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            0
# Loan_Amount_Term     11
# Credit_History       30
# Property_Area         0
# Loan_Status           0
# PLoan_ID              0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop(['Loan_Status', 'Loan_ID', 'PLoan_ID'], axis=1)

# %%
y=df['Loan_Status']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.33,random_state=42)

# %%
X_train.shape
# Out:
# (227, 11)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knc = KNeighborsClassifier()

# %%
model_knc.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
accuracy_knc
# Out:
# 0.6548672566371682

# %%
y_pred = model_knc.predict(X_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[10, 23],
#        [16, 64]])

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred=model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.831858407079646

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=model.predict(X_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7699115044247787

# %%
from sklearn.ensemble import VotingClassifier

# %%
model=VotingClassifier(estimators=[('knc',model_knc),('rfc',model),('dtc',model)],voting='hard')

# %%
model.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('knc', KNeighborsClassifier()),
#                              ('rfc', DecisionTreeClassifier()),
#                              ('dtc', DecisionTreeClassifier())])

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7699115044247787

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[13, 20],
#        [ 6, 74]])

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.39      0.50        33
#            1       0.79      0.93      0.85        80
#
#     accuracy                           0.77       113
#    macro avg       0.74      0.66      0.68       113
# weighted avg       0.76      0.77      0.75       113
